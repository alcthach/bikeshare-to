# %% [markdown]
# # Profiling csv generated from `stations` object
# 2023-01-24
# alcthach@gmail.com

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../src/python_scripts/stations/data_file.csv')

# %%
df_stations = pd.read_csv('../src/python_scripts/stations/stations.csv')

# %%
df_stations
# Out:
#     physical_configuration rental_uris        lon cross_street  \
# 0                  REGULAR          {} -79.395954          NaN
# 1      ELECTRICBIKESTATION          {} -79.383550          NaN
# 2                  REGULAR          {} -79.399429          NaN
# 3                  REGULAR          {} -79.402761          NaN
# 4                  REGULAR          {} -79.389099          NaN
# ..                     ...         ...        ...          ...
# 648    ELECTRICBIKESTATION          {} -79.394635          NaN
# 649                  VAULT          {} -79.516278          NaN
# 650                  VAULT          {} -79.511912          NaN
# 651                  VAULT          {} -79.491800          NaN
# 652                REGULAR          {} -79.370638          NaN
#
#              groups  nearby_distance                               name  \
# 0                []            500.0       Fort York  Blvd / Capreol Ct
# ...
